# %% [markdown]
# LAB 7:
# PHÂN TÍCH DỮ LIỆU DẠNG VĂN BẢN VỚI NLTK

# %% [markdown]
# 1. Giới thiệu về thư viện NLTK:

# %%
import nltk 
nltk.download_shell()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader>  d
# Download which package (l=list; x=cancel)?
#   Identifier>  1
#     Error loading 1: Package '1' not found in index
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader>  d
# Download which package (l=list; x=cancel)?
#   Identifier>  gutenberg
# ...
#         C:\Users\US\AppData\Roaming\nltk_data...
#       Package gutenberg is already up-to-date!
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ...

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\US\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
gb = nltk.corpus.gutenberg 
print("Gutenberg files : ", gb.fileids())
# Out:
# Gutenberg files :  ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
macbeth = nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')

# %%
len(macbeth)
# Out:
# 23140

# %%
macbeth [:10]
# Out:
# ['[',
#  'The',
#  'Tragedie',
#  'of',
#  'Macbeth',
#  'by',
#  'William',
#  'Shakespeare',
#  '1603',
#  ']']

# %%
macbeth_sents = nltk.corpus.gutenberg.sents('shakespeare-macbeth.txt')
macbeth_sents[:5]
# Out:
# [['[',
#   'The',
#   'Tragedie',
#   'of',
#   'Macbeth',
#   'by',
#   'William',
#   'Shakespeare',
#   '1603',
#   ']'],
#  ['Actus', 'Primus', '.'],
#  ['Scoena', 'Prima', '.'],
#  ['Thunder', 'and', 'Lightning', '.'],
#  ['Enter', 'three', 'Witches', '.']]

# %% [markdown]
# 2. Tìm 1 từ với NLTK:

# %%
text = nltk.Text(macbeth) 
text.concordance('Stage')
# Out:
# Displaying 3 of 3 matches:
# nts with Dishes and Seruice ouer the Stage . Then enter Macbeth Macb . If it we
# with mans Act , Threatens his bloody Stage : byth ' Clock ' tis Day , And yet d
#  struts and frets his houre vpon the Stage , And then is heard no more . It is

# %%
text.common_contexts(['Stage'])
# Out:
# the_. bloody_: the_,

# %%
text.similar('Stage')
# Out:
# day time face warre ayre king bleeding man reuolt serieant like
# knowledge broyle shew head spring heeles hare thane skie

# %% [markdown]
#     3. Phân tích tần số của các từ

# %%
fd = nltk.FreqDist(macbeth) 
fd.most_common(10)
# Out:
# [(',', 1962),
#  ('.', 1235),
#  ("'", 637),
#  ('the', 531),
#  (':', 477),
#  ('and', 376),
#  ('I', 333),
#  ('of', 315),
#  ('to', 311),
#  ('?', 241)]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\US\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sw = set(nltk.corpus.stopwords.words('english'))
print(len(sw))
list(sw)[:10]
# Out:
# 198
# ['over',
#  'ourselves',
#  'ours',
#  "weren't",
#  'what',
#  'will',
#  'can',
#  'those',
#  'needn',
#  'aren']

# %%
macbeth_filtered = [w for w in macbeth if w.lower() not in sw]
len(macbeth_filtered)
# Out:
# 14946

# %%
fd = nltk.FreqDist(macbeth_filtered)
fd.most_common(10)
# Out:
# [(',', 1962),
#  ('.', 1235),
#  ("'", 637),
#  (':', 477),
#  ('?', 241),
#  ('Macb', 137),
#  ('haue', 117),
#  ('-', 100),
#  ('Enter', 80),
#  ('thou', 63)]

# %%
import string 
punctuation = set(string.punctuation) 
macbeth_filtered2 = [w.lower() for w in macbeth if w.lower() not in sw and w.lower() not in punctuation] 
fd = nltk.FreqDist(macbeth_filtered2) 
fd.most_common(10)
# Out:
# [('macb', 137),
#  ('haue', 122),
#  ('thou', 90),
#  ('enter', 81),
#  ('shall', 68),
#  ('macbeth', 62),
#  ('vpon', 62),
#  ('thee', 61),
#  ('macd', 58),
#  ('vs', 57)]

# %% [markdown]
# 4. Lựa chọn các từ trong văn bản

# %%
long_words = [w for w in macbeth if len(w)> 12] 
sorted(long_words)
# Out:
# ['Assassination',
#  'Chamberlaines',
#  'Distinguishes',
#  'Gallowgrosses',
#  'Metaphysicall',
#  'Northumberland',
#  'Voluptuousnesse',
#  'commendations',
#  'multitudinous',
#  'supernaturall',
#  'vnaccompanied']

# %%
ious_words = [w for w in macbeth if 'ious' in w] 
ious_words = set(ious_words) 
sorted(ious_words)
# Out:
# ['Auaricious',
#  'Gracious',
#  'Industrious',
#  'Iudicious',
#  'Luxurious',
#  'Malicious',
#  'Obliuious',
#  'Pious',
#  'Rebellious',
#  'compunctious',
#  'furious',
#  'gracious',
#  'pernicious',
#  'pernitious',
#  'pious',
#  'precious',
#  'rebellious',
#  'sacrilegious',
#  'serious',
#  'spacious',
#  'tedious']

# %% [markdown]
# 5. Bigrams và collocations

# %%
bgrms = nltk.FreqDist(nltk.bigrams(macbeth_filtered2)) 
bgrms.most_common(15)
# Out:
# [(('enter', 'macbeth'), 16),
#  (('exeunt', 'scena'), 15),
#  (('thane', 'cawdor'), 13),
#  (('knock', 'knock'), 10),
#  (('st', 'thou'), 9),
#  (('thou', 'art'), 9),
#  (('lord', 'macb'), 9),
#  (('haue', 'done'), 8),
#  (('macb', 'haue'), 8),
#  (('good', 'lord'), 8),
#  (('let', 'vs'), 7),
#  (('enter', 'lady'), 7),
#  (('wee', 'l'), 7),
#  (('would', 'st'), 6),
#  (('macbeth', 'macb'), 6)]

# %%
tgrms = nltk.FreqDist(nltk.trigrams (macbeth_filtered2)) 
tgrms.most_common(10)
# Out:
# [(('knock', 'knock', 'knock'), 6),
#  (('enter', 'macbeth', 'macb'), 5),
#  (('enter', 'three', 'witches'), 4),
#  (('exeunt', 'scena', 'secunda'), 4),
#  (('good', 'lord', 'macb'), 4),
#  (('three', 'witches', '1'), 3),
#  (('exeunt', 'scena', 'tertia'), 3),
#  (('thunder', 'enter', 'three'), 3),
#  (('exeunt', 'scena', 'quarta'), 3),
#  (('scena', 'prima', 'enter'), 3)]

# %% [markdown]
# 6. Sử dụng văn bản trên mạng

# %%
from urllib import request 
url = "http://www.gutenberg.org/files/2554/2554-0.txt" 
response = request.urlopen(url) 
raw = response.read().decode('utf8') 
raw[:75]
# Out:
# '*** START OF THE PROJECT GUTENBERG EBOOK 2554 ***\n\n\n\n\nCRIME AND PUNISHMENT\n'

# %%
from urllib import request 
url = "http://www.gutenberg.org/files/2554/2554-0.txt" 
response = request.urlopen(url) 
raw = response.read().decode('utf-8-sig') 
raw[:75]
# Out:
# '*** START OF THE PROJECT GUTENBERG EBOOK 2554 ***\n\n\n\n\nCRIME AND PUNISHMENT\n'

# %%
tokens = nltk.word_tokenize (raw) 
webtext = nltk.Text (tokens) 
webtext[:12]
# Out:
# ['*',
#  '*',
#  '*',
#  'START',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  '2554',
#  '*',
#  '*']

# %% [markdown]
# 7. Rút trích văn bản từ trang html

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm" 
html = request.urlopen(url).read().decode('utf8') 
html[:120]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">\r\n<html>\r\n<hea'

# %%
# %pip install lxml
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
from bs4 import BeautifulSoup 
raw = BeautifulSoup(html, "lxml").get_text()
tokens = nltk.word_tokenize(raw) 
text = nltk.Text(tokens)

# %% [markdown]
# 8. Phân tích cảm xúc người dùng

# %%
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\US\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %%
import random 
reviews = nltk.corpus.movie_reviews 
documents = [(list(reviews.words(fileid)), category)
for category in reviews.categories()
for fileid in reviews.fileids(category)] 
random.shuffle(documents)

# %%
first_review = ' '.join(documents[0][0]) 
print(first_review)
# Out:
# 1989 ' s " major league " was a delightful surprise . i didn ' t expect much of it when i decided to watch it on cable , but it proved to be fresh and funny . however , when the appeal of a movie is its freshness , the sequels are virtually guaranteed to be stale . that ' s certainly true of " major league ii " and the most recent entry , " major league : back to the minors . " the title is , of course , a contradiction . shouldn ' t it be " minor league ? " that contradiction suggests the lengths to which writer / director john warren has gone to squeeze a third movie out of the formula established by the first movie . original stars charlie sheen and tom berenger ( who returned for " major league ii " ) are not around , leaving corbin bernsen the only original headliner to make the third movie . the other veterans who return ( dennis haysbert as voodoo - inspired batter cerrano and takaaki ishibashi as tanaka , who was introduced in " league ii " ) seem to be around just to lend le
# ...

# %%
documents[0][1]
# Out:
# 'neg'

# %%
all_words = nltk.FreqDist(w.lower() for w in reviews.words()) 
word_features = list(all_words)

# %%
def document_features(document, word_features): 
    document_words = set(document) 
    features = {} 
    for word in word_features: 
        features['{}'.format(word)] = (word in document_words) 
    return features

# %%
featuresets = [(document_features(d,word_features), c) for (d,c) in documents] 
len(featuresets)
# Out:
# 2000

# %%
train_set, test_set = featuresets[1500:], featuresets[:500] 
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
train_set, est_set = featuresets[1500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.774

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#                concerned = True              pos : neg    =      9.4 : 1.0
#                     fits = True              pos : neg    =      9.4 : 1.0
#                  failure = True              neg : pos    =      9.2 : 1.0
#                   wasted = True              neg : pos    =      9.1 : 1.0
#                  carries = True              pos : neg    =      8.7 : 1.0
#               refreshing = True              pos : neg    =      8.7 : 1.0
#              outstanding = True              pos : neg    =      8.6 : 1.0
#                 terrific = True              pos : neg    =      8.2 : 1.0
#            extraordinary = True              pos : neg    =      8.0 : 1.0
#                  idiotic = True              neg : pos    =      7.9 : 1.0

# %% [markdown]
# 9. Bài tập áp dụng

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('tagsets')
nltk.download('names')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\US\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\US\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\US\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\US\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\US\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!
# True

# %% [markdown]
# 1. Liệt kê các tên của corpus (kho ngữ liệu) có sẵn trong NLTK

# %%
import os
import nltk

# Tìm đường dẫn đến thư mục chứa corpora của NLTK
corpora_path = nltk.data.find('corpora')

print("Danh sách các corpus phổ biến có trong thư mục dữ liệu của NLTK:")

# Sử dụng os.listdir để liệt kê các thư mục/file con bên trong
for name in os.listdir(corpora_path):
    # Kiểm tra nếu là thư mục hoặc các file dữ liệu (bỏ qua các file hệ thống ẩn nếu có)
    if not name.startswith('.'):
        print("- ", name)
# Out:
# Danh sách các corpus phổ biến có trong thư mục dữ liệu của NLTK:
# -  gutenberg
# -  gutenberg.zip
# -  movie_reviews
# -  movie_reviews.zip
# -  names
# -  names.zip
# -  omw-1.4.zip
# -  stopwords
# -  stopwords.zip
# -  wordnet.zip

# %% [markdown]
# 2. Liệt kê danh sách các ngôn ngữ hỗ trợ stopwords

# %%
from nltk.corpus import stopwords

languages = stopwords.fileids()
print("Số lượng ngôn ngữ hỗ trợ stopwords:", len(languages))
print("Danh sách các ngôn ngữ:")
print(languages)
# Out:
# Số lượng ngôn ngữ hỗ trợ stopwords: 33
# Danh sách các ngôn ngữ:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']

# %% [markdown]
# 3. Kiểm tra danh sách stopwords của một số ngôn ngữ cụ thể

# %%
from nltk.corpus import stopwords

# Xem thử stopwords của tiếng Anh và tiếng Pháp
print("10 Stopwords đầu tiên trong tiếng Anh:")
print(stopwords.words('english')[:10])

print("\n10 Stopwords đầu tiên trong tiếng Pháp:")
print(stopwords.words('french')[:10])
# Out:
# 10 Stopwords đầu tiên trong tiếng Anh:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
#
# 10 Stopwords đầu tiên trong tiếng Pháp:
# ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle']

# %% [markdown]
# 4. Loại bỏ các stopwords từ một văn bản cho trước

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

text = "Natural Language Processing with Python and NLTK is very interesting and useful."
stop_words = set(stopwords.words('english'))

# Tách từ (Tokenize)
words = word_tokenize(text)

# Lọc bỏ stopwords
filtered_text = [w for w in words if w.lower() not in stop_words]

print("Văn bản gốc:", words)
print("Sau khi lọc stopwords:", filtered_text)
# Out:
# Văn bản gốc: ['Natural', 'Language', 'Processing', 'with', 'Python', 'and', 'NLTK', 'is', 'very', 'interesting', 'and', 'useful', '.']
# Sau khi lọc stopwords: ['Natural', 'Language', 'Processing', 'Python', 'NLTK', 'interesting', 'useful', '.']

# %% [markdown]
# 5. Bỏ qua (loại trừ) một số từ ra khỏi danh sách stopwords gốc

# %%
from nltk.corpus import stopwords

# Lấy danh sách gốc
stop_words = set(stopwords.words('english'))

# Các từ muốn giữ lại
words_to_keep = {'not', 'no'}
filtered_stopwords = stop_words - words_to_keep

print("Từ 'not' có trong danh sách gốc không?", 'not' in stop_words)
print("Từ 'not' có trong danh sách mới không?", 'not' in filtered_stopwords)
# Out:
# Từ 'not' có trong danh sách gốc không? True
# Từ 'not' có trong danh sách mới không? False

# %% [markdown]
# 6. Tìm định nghĩa và ví dụ của một từ bằng WordNet

# %%
from nltk.corpus import wordnet

word = "bank"
synsets = wordnet.synsets(word)

print(f"Từ '{word}' có {len(synsets)} nghĩa (synsets) khác nhau trong WordNet.\n")
for idx, syn in enumerate(synsets[:3], 1): # Lấy tối đa 3 nghĩa đầu tiên
    print(f"Nghĩa {idx} ({syn.name()}):")
    print(" - Định nghĩa:", syn.definition())
    print(" - Ví dụ:", syn.examples())
# Out:
# Từ 'bank' có 18 nghĩa (synsets) khác nhau trong WordNet.
#
# Nghĩa 1 (bank.n.01):
#  - Định nghĩa: sloping land (especially the slope beside a body of water)
#  - Ví dụ: ['they pulled the canoe up on the bank', 'he sat on the bank of the river and watched the currents']
# Nghĩa 2 (depository_financial_institution.n.01):
#  - Định nghĩa: a financial institution that accepts deposits and channels the money into lending activities
#  - Ví dụ: ['he cashed a check at the bank', 'that bank holds the mortgage on my home']
# Nghĩa 3 (bank.n.03):
#  - Định nghĩa: a long ridge or pile
#  - Ví dụ: ['a huge bank of earth']

# %% [markdown]
# 7. Tìm tập hợp từ đồng nghĩa (Synonyms) và trái nghĩa (Antonyms)

# %%
from nltk.corpus import wordnet

synonyms = []
antonyms = []

word = "good"
for syn in wordnet.synsets(word):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())

print(f"Từ đồng nghĩa của '{word}':", set(synonyms))
print(f"Từ trái nghĩa của '{word}':", set(antonyms))
# Out:
# Từ đồng nghĩa của 'good': {'skilful', 'unspoiled', 'respectable', 'good', 'goodness', 'unspoilt', 'estimable', 'just', 'skillful', 'sound', 'beneficial', 'upright', 'salutary', 'proficient', 'secure', 'practiced', 'honest', 'trade_good', 'in_force', 'ripe', 'undecomposed', 'honorable', 'serious', 'expert', 'in_effect', 'soundly', 'commodity', 'well', 'dear', 'thoroughly', 'full', 'safe', 'right', 'near', 'dependable', 'adept', 'effective'}
# Từ trái nghĩa của 'good': {'bad', 'ill', 'evilness', 'badness', 'evil'}

# %% [markdown]
# 8. Tổng quan về bộ tag (POS Tags) và chi tiết bằng RegEx

# %%
import nltk

print("--- Tổng quan về bộ tag Penn Treebank ---")
nltk.help.upenn_tagset()

print("\n--- Chi tiết của một tag cụ thể (ví dụ: NN - Noun) ---")
nltk.help.upenn_tagset('NN')

print("\n--- Tìm các tag liên quan đến Động từ (bắt đầu bằng VB) bằng RegEx ---")
nltk.help.upenn_tagset('VB.*')
# Out:
# --- Tổng quan về bộ tag Penn Treebank ---
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %% [markdown]
# 9. So sánh sự giống nhau của hai danh từ

# %%
from nltk.corpus import wordnet

# Lấy nghĩa danh từ (noun) của hai từ
dog = wordnet.synset('dog.n.01')
cat = wordnet.synset('cat.n.01')

# Tính độ tương đồng Wu-Palmer
similarity = dog.wup_similarity(cat)
print(f"Độ tương đồng giữa 'dog' và 'cat': {similarity:.4f}")
# Out:
# Độ tương đồng giữa 'dog' và 'cat': 0.8571

# %% [markdown]
# 10. So sánh sự giống nhau của hai động từ

# %%
from nltk.corpus import wordnet

# Lấy nghĩa động từ (verb) của hai từ
run = wordnet.synset('run.v.01')
walk = wordnet.synset('walk.v.01')

similarity = run.wup_similarity(walk)
print(f"Độ tương đồng giữa 'run' và 'walk': {similarity:.4f}")
# Out:
# Độ tương đồng giữa 'run' và 'walk': 0.2857

# %% [markdown]
# 11. Số lượng tên nam/nữ trong corpus names. In 10 tên đầu tiên

# %%
from nltk.corpus import names

male_names = names.words('male.txt')
female_names = names.words('female.txt')

print(f"Tổng số tên Nam: {len(male_names)}")
print(f"Tổng số tên Nữ: {len(female_names)}\n")

print("10 Tên Nam đầu tiên:", male_names[:10])
print("10 Tên Nữ đầu tiên:", female_names[:10])
# Out:
# Tổng số tên Nam: 2943
# Tổng số tên Nữ: 5001
#
# 10 Tên Nam đầu tiên: ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
# 10 Tên Nữ đầu tiên: ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']

# %% [markdown]
# 12. Trộn và in 15 kết hợp ngẫu nhiên tên nam và nữ có gắn nhãn

# %%
import random
from nltk.corpus import names

# Gắn nhãn cho từng tên
labeled_names = ([(name, 'male') for name in names.words('male.txt')] +
                 [(name, 'female') for name in names.words('female.txt')])

# Trộn ngẫu nhiên danh sách
random.shuffle(labeled_names)

print("15 kết hợp ngẫu nhiên đầu tiên được gắn nhãn:")
for name, gender in labeled_names[:15]:
    print(f"- Tên: {name} ({gender})")
# Out:
# 15 kết hợp ngẫu nhiên đầu tiên được gắn nhãn:
# - Tên: Margo (female)
# - Tên: Adaline (female)
# - Tên: Broderick (male)
# - Tên: Dwaine (male)
# - Tên: Giff (male)
# - Tên: Ronen (male)
# - Tên: Jeffrey (male)
# - Tên: Isabelita (female)
# - Tên: Mariana (female)
# - Tên: Mylo (male)
# - Tên: Cassie (female)
# - Tên: Talbot (male)
# - Tên: Kandy (female)
# - Tên: Merilyn (female)
# - Tên: Aigneis (female)

# %% [markdown]
# 13. Trích xuất ký tự cuối cùng của tên và tạo mảng dữ liệu mới

# %%
from nltk.corpus import names

labeled_names = ([(name, 'male') for name in names.words('male.txt')] +
                 [(name, 'female') for name in names.words('female.txt')])

# Tạo mảng mới chứa: (Kí tự cuối cùng, Nhãn giới tính)
last_letters_dataset = [(name[-1].lower(), gender) for name, gender in labeled_names]

print("Mẫu 10 phần tử đầu tiên trong mảng mới:")
for char, label in last_letters_dataset[:10]:
    print(f"Chữ cái cuối: '{char}' -> Nhãn: {label}")
# Out:
# Mẫu 10 phần tử đầu tiên trong mảng mới:
# Chữ cái cuối: 'r' -> Nhãn: male
# Chữ cái cuối: 'n' -> Nhãn: male
# Chữ cái cuối: 'y' -> Nhãn: male
# Chữ cái cuối: 'e' -> Nhãn: male
# Chữ cái cuối: 't' -> Nhãn: male
# Chữ cái cuối: 't' -> Nhãn: male
# Chữ cái cuối: 'y' -> Nhãn: male
# Chữ cái cuối: 'l' -> Nhãn: male
# Chữ cái cuối: 'l' -> Nhãn: male
# Chữ cái cuối: 'm' -> Nhãn: male
